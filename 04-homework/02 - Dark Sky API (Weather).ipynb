# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
response = requests.get('https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/12,77')
print(type(response))
data_weather = response.json()
print(type(data_weather))
print(data_weather)
# Out:
# <class 'requests.models.Response'>
# <class 'dict'>
# {'latitude': 12, 'longitude': 77, 'timezone': 'Asia/Kolkata', 'currently': {'time': 1560253019, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.0043, 'precipProbability': 0.09, 'precipType': 'rain', 'temperature': 85.14, 'apparentTemperature': 90.05, 'dewPoint': 70.46, 'humidity': 0.62, 'pressure': 1005.38, 'windSpeed': 17.1, 'windGust': 29.89, 'windBearing': 225, 'cloudCover': 0.74, 'uvIndex': 1, 'visibility': 6.48, 'ozone': 273.43}, 'hourly': {'summary': 'Light rain tomorrow morning.', 'icon': 'rain', 'data': [{'time': 1560252600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.0049, 'precipProbability': 0.1, 'precipType': 'rain', 'temperature': 85.51, 'apparentTemperature': 90.56, 'dewPoint': 70.56, 'humidity': 0.61, 'pressure': 1005.32, 'windSpeed': 17.36, 'windGust': 29.96, 'windBearing': 225, 'cloudCover': 0.73, 'uvIndex': 1, 'visibility': 6.18, 'ozone': 273.38}, {'time': 1560256200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 82.38, 'apparentTemperature': 86.14, 'dewPoint': 69.66, 'humidity': 0.66, 'pressure': 1005.8, 'windSpeed': 15.14, 'windGust': 29.36, 'windBearing': 228, 'cloudCover': 0.75, 'uvIndex': 0, 'visibility': 8.73, 'ozone': 273.86}, {'time': 1560259800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 78.52, 'apparentTemperature': 79.42, 'dewPoint': 68.38, 'humidity': 0.71, 'pressure': 1006.47, 'windSpeed': 12.28, 'windGust': 27.62, 'windBearing': 237, 'cloudCover': 0.76, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.1}, {'time': 1560263400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 76.54, 'apparentTemperature': 77.39, 'dewPoint': 67.71, 'humidity': 0.74, 'pressure': 1007.16, 'windSpeed': 10.51, 'windGust': 25.47, 'windBearing': 241, 'cloudCover': 0.72, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.35}, {'time': 1560267000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0002, 'precipProbability': 0.16, 'precipType': 'rain', 'temperature': 75.85, 'apparentTemperature': 76.68, 'dewPoint': 67.5, 'humidity': 0.75, 'pressure': 1007.73, 'windSpeed': 9.3, 'windGust': 23.28, 'windBearing': 240, 'cloudCover': 0.68, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.71}, {'time': 1560270600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 75.33, 'apparentTemperature': 76.15, 'dewPoint': 67.34, 'humidity': 0.76, 'pressure': 1008.18, 'windSpeed': 8.08, 'windGust': 21.08, 'windBearing': 236, 'cloudCover': 0.7, 'uvIndex': 0, 'visibility': 10, 'ozone': 275.25}, {'time': 1560274200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 74.88, 'apparentTemperature': 75.69, 'dewPoint': 67.19, 'humidity': 0.77, 'pressure': 1008.42, 'windSpeed': 7.11, 'windGust': 19.4, 'windBearing': 233, 'cloudCover': 0.74, 'uvIndex': 0, 'visibility': 10, 'ozone': 275.85}, {'time': 1560277800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 74.39, 'apparentTemperature': 75.19, 'dewPoint': 67.06, 'humidity': 0.78, 'pressure': 1008.25, 'windSpeed': 6.69, 'windGust': 19.23, 'windBearing': 229, 'cloudCover': 0.78, 'uvIndex': 0, 'visibility': 10, 'ozone': 276.45}, {'time': 1560281400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 73.9, 'apparentTemperature': 74.7, 'dewPoint': 66.95, 'humidity': 0.79, 'pressure': 1007.67, 'windSpeed': 6.84, 'windGust': 20.56, 'windBearing': 225, 'cloudCover': 0.81, 'uvIndex': 0, 'visibility': 10, 'ozone': 277.05}, {'time': 1560285000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability' ...

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
data_weather['currently']['windSpeed']
# Out:
# 17.1

# %%
diff = data_weather['currently']['apparentTemperature'] - data_weather['currently']['temperature']

# %%
diff
# Out:
# 4.909999999999997

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
url = https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/12,77
# Out:
#   File "<ipython-input-14-aa9dfdadcd4d>", line 1
#     url = https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/12,77
#                ^
# SyntaxError: invalid syntax

# %%
response = requests.get('https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/12,77')
data_forecast = response.json()
print(data_forecast)
# Out:
# {'latitude': 12, 'longitude': 77, 'timezone': 'Asia/Kolkata', 'currently': {'time': 1560253642, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.0035, 'precipProbability': 0.07, 'precipType': 'rain', 'temperature': 83.65, 'apparentTemperature': 88.13, 'dewPoint': 70.38, 'humidity': 0.64, 'pressure': 1005.46, 'windSpeed': 18.24, 'windGust': 26.86, 'windBearing': 250, 'cloudCover': 0.72, 'uvIndex': 1, 'visibility': 7.85, 'ozone': 273.52}, 'hourly': {'summary': 'Light rain tomorrow morning.', 'icon': 'rain', 'data': [{'time': 1560252600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.0049, 'precipProbability': 0.1, 'precipType': 'rain', 'temperature': 84.01, 'apparentTemperature': 88.63, 'dewPoint': 70.45, 'humidity': 0.64, 'pressure': 1005.32, 'windSpeed': 18.55, 'windGust': 26.99, 'windBearing': 250, 'cloudCover': 0.73, 'uvIndex': 1, 'visibility': 7.77, 'ozone': 273.38}, {'time': 1560256200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 82.77, 'apparentTemperature': 86.9, 'dewPoint': 70.18, 'humidity': 0.66, 'pressure': 1005.8, 'windSpeed': 17.5, 'windGust': 26.54, 'windBearing': 249, 'cloudCover': 0.68, 'uvIndex': 0, 'visibility': 8.04, 'ozone': 273.86}, {'time': 1560259800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 80.32, 'apparentTemperature': 83.36, 'dewPoint': 69.27, 'humidity': 0.69, 'pressure': 1006.47, 'windSpeed': 14.87, 'windGust': 25.77, 'windBearing': 248, 'cloudCover': 0.66, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.1}, {'time': 1560263400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 77.38, 'apparentTemperature': 78.25, 'dewPoint': 68.08, 'humidity': 0.73, 'pressure': 1007.16, 'windSpeed': 11.41, 'windGust': 24.94, 'windBearing': 244, 'cloudCover': 0.68, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.35}, {'time': 1560267000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0002, 'precipProbability': 0.16, 'precipType': 'rain', 'temperature': 75.85, 'apparentTemperature': 76.68, 'dewPoint': 67.5, 'humidity': 0.75, 'pressure': 1007.73, 'windSpeed': 9.3, 'windGust': 23.28, 'windBearing': 240, 'cloudCover': 0.68, 'uvIndex': 0, 'visibility': 10, 'ozone': 274.71}, {'time': 1560270600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 75.33, 'apparentTemperature': 76.15, 'dewPoint': 67.34, 'humidity': 0.76, 'pressure': 1008.18, 'windSpeed': 8.08, 'windGust': 21.08, 'windBearing': 236, 'cloudCover': 0.7, 'uvIndex': 0, 'visibility': 10, 'ozone': 275.25}, {'time': 1560274200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 74.88, 'apparentTemperature': 75.69, 'dewPoint': 67.19, 'humidity': 0.77, 'pressure': 1008.42, 'windSpeed': 7.11, 'windGust': 19.4, 'windBearing': 233, 'cloudCover': 0.74, 'uvIndex': 0, 'visibility': 10, 'ozone': 275.85}, {'time': 1560277800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 74.39, 'apparentTemperature': 75.19, 'dewPoint': 67.06, 'humidity': 0.78, 'pressure': 1008.25, 'windSpeed': 6.69, 'windGust': 19.23, 'windBearing': 229, 'cloudCover': 0.78, 'uvIndex': 0, 'visibility': 10, 'ozone': 276.45}, {'time': 1560281400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 73.9, 'apparentTemperature': 74.7, 'dewPoint': 66.95, 'humidity': 0.79, 'pressure': 1007.67, 'windSpeed': 6.84, 'windGust': 20.56, 'windBearing': 225, 'cloudCover': 0.81, 'uvIndex': 0, 'visibility': 10, 'ozone': 277.05}, {'time': 1560285000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': ...

# %%
data_forecast['currently']['summary']
# Out:
# 'Mostly Cloudy'

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
#running for daily key bc others don't have this?

# %%
diff = data_forecast['daily']['data'][0]['temperatureHigh'] - data_forecast['daily']['data'][0]['temperatureLow']
diff
# Out:
# 13.179999999999993

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
response = requests.get('https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/12,77?units=si')
data_forecast = response.json()
print(data_forecast)
# Out:
# {'latitude': 12, 'longitude': 77, 'timezone': 'Asia/Kolkata', 'currently': {'time': 1560255204, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.033, 'precipProbability': 0.03, 'precipType': 'rain', 'temperature': 28.28, 'apparentTemperature': 30.61, 'dewPoint': 21.22, 'humidity': 0.66, 'pressure': 1005.57, 'windSpeed': 7.96, 'windGust': 10.83, 'windBearing': 252, 'cloudCover': 0.74, 'uvIndex': 0, 'visibility': 14.79, 'ozone': 274.44}, 'hourly': {'summary': 'Light rain tomorrow morning.', 'icon': 'rain', 'data': [{'time': 1560252600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0.1219, 'precipProbability': 0.1, 'precipType': 'rain', 'temperature': 28.82, 'apparentTemperature': 31.35, 'dewPoint': 21.33, 'humidity': 0.64, 'pressure': 1005.22, 'windSpeed': 8.22, 'windGust': 10.68, 'windBearing': 252, 'cloudCover': 0.75, 'uvIndex': 1, 'visibility': 14.68, 'ozone': 274.04}, {'time': 1560256200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-day', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 28.08, 'apparentTemperature': 30.32, 'dewPoint': 21.17, 'humidity': 0.66, 'pressure': 1005.71, 'windSpeed': 7.85, 'windGust': 10.89, 'windBearing': 251, 'cloudCover': 0.74, 'uvIndex': 0, 'visibility': 14.84, 'ozone': 274.59}, {'time': 1560259800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 26.78, 'apparentTemperature': 28.44, 'dewPoint': 20.67, 'humidity': 0.69, 'pressure': 1006.41, 'windSpeed': 6.71, 'windGust': 10.81, 'windBearing': 249, 'cloudCover': 0.76, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 275.19}, {'time': 1560263400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 25.3, 'apparentTemperature': 25.78, 'dewPoint': 20.03, 'humidity': 0.73, 'pressure': 1007.14, 'windSpeed': 5.18, 'windGust': 10.63, 'windBearing': 245, 'cloudCover': 0.81, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 275.85}, {'time': 1560267000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0051, 'precipProbability': 0.19, 'precipType': 'rain', 'temperature': 24.53, 'apparentTemperature': 24.99, 'dewPoint': 19.72, 'humidity': 0.75, 'pressure': 1007.7, 'windSpeed': 4.33, 'windGust': 10.38, 'windBearing': 240, 'cloudCover': 0.82, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 276.45}, {'time': 1560270600, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 24.23, 'apparentTemperature': 24.69, 'dewPoint': 19.65, 'humidity': 0.76, 'pressure': 1008.11, 'windSpeed': 3.93, 'windGust': 10.09, 'windBearing': 236, 'cloudCover': 0.82, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 277.11}, {'time': 1560274200, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.97, 'apparentTemperature': 24.42, 'dewPoint': 19.59, 'humidity': 0.77, 'pressure': 1008.31, 'windSpeed': 3.57, 'windGust': 9.78, 'windBearing': 232, 'cloudCover': 0.83, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 277.77}, {'time': 1560277800, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.69, 'apparentTemperature': 24.14, 'dewPoint': 19.53, 'humidity': 0.78, 'pressure': 1008.13, 'windSpeed': 3.33, 'windGust': 9.4, 'windBearing': 228, 'cloudCover': 0.84, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 278.3}, {'time': 1560281400, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 23.42, 'apparentTemperature': 23.87, 'dewPoint': 19.47, 'humidity': 0.79, 'pressure': 1007.6, 'windSpeed': 3.2, 'windGust': 8.93, 'windBearing': 225, 'cloudCover': 0.85, 'uvIndex': 0, 'visibility': 16.09, 'ozone': 278.72}, {'time': 1560285000, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0, ' ...

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
data_forecast['daily']['data'][0]['temperatureHighTime']
# Out:
# 1560234600

# %%
data_forecast['daily']['data'][0]['temperatureLowTime']

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
# Out:
#   File "<ipython-input-46-4d4fc94015ba>", line 2
#     https://darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/25.7776,-80.2192
#            ^
# SyntaxError: invalid syntax

# %%
# Out:
# {'latitude': 25.7617,
#  'longitude': 80.1918,
#  'timezone': 'Asia/Kolkata',
#  'currently': {'time': 1560255659,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 115.45,
#   'apparentTemperature': 115.45,
#   'dewPoint': 48.84,
#   'humidity': 0.11,
#   'pressure': 992.69,
#   'windSpeed': 6.51,
#   'windGust': 10.28,
#   'windBearing': 349,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 287.96},
#  'hourly': {'summary': 'Partly cloudy starting tonight, continuing until tomorrow morning.',
#   'icon': 'partly-cloudy-night',
#   'data': [{'time': 1560252600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 116.64,
#     'apparentTemperature': 116.64,
#     'dewPoint': 48.73,
#     'humidity': 0.11,
#     'pressure': 992.65,
#     'windSpeed': 6.64,
#     'windGust': 10.58,
#     'windBearing': 343,
#     'cloudCover': 0,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 288.17},
#    {'time': 1560256200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 115.24,
#     'apparentTemperature': 115.24,
#     'dewPoint': 48.86,
#     'humidity': 0.12,
#     'pressure': 992.7,
#     'windSpeed': 6.49,
#     'windGust': 10.23,
#     'windBearing': 350,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.92},
#    {'time': 1560259800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 112.76,
#     'apparentTemperature': 112.76,
#     'dewPoint': 49.44,
#     'humidity': 0.13,
#     'pressure': 993.13,
#     'windSpeed': 6.36,
#     'windGust': 10.26,
#     'windBearing': 3,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.69},
#    {'time': 1560263400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 109.86,
#     'apparentTemperature': 109.86,
#     'dewPoint': 50,
#     'humidity': 0.14,
#     'pressure': 993.71,
#     'windSpeed': 6.36,
#     'windGust': 10.24,
#     'windBearing': 20,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.5},
#    {'time': 1560267000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 107.76,
#     'apparentTemperature': 107.76,
#     'dewPoint': 50.17,
#     'humidity': 0.15,
#     'pressure': 994.29,
#     'windSpeed': 6.67,
#     'windGust': 9.88,
#     'windBearing': 36,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.38},
#    {'time': 1560270600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 106.54,
#     'apparentTemperature': 106.54,
#     'dewPoint': 50.03,
#     'humidity': 0.16,
#     'pressure': 994.86,
#     'windSpeed': 7.14,
#     'windGust': 9.17,
#     'windBearing': 50,
#     'cloudCover': 0.17,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.31},
#    {'time': 1560274200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 105.58,
#     'apparentTemperature': 105.58,
#     'dewPoint': 49.99,
#     'humidity': 0.16,
#     'pressure': 995.32,
#     'windSpeed': 7.59,
#     'windGust': 8.4,
#     'windBearing': 63,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.29},
#    {'time': 1560277800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 104.44,
#     'apparentTemperature': 104.44,
#     'dewPoint': 50.35,
#     'humidity': 0.17,
#     'pressure': 995.49,
#     'windSpeed': 7.61,
#     'windGust': 7.88,
#     'windBearing': 72,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.26},
#    {'time': 1560281400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 103.03,
#     'apparentTemperature': 103.03,
#     'dewPoint': 51.06,
#     'humidity': 0.18,
#     'pressure': 995.36,
#     'windSpeed': 7.19,
#     'windGust': 7.35,
#     'windBearing': 76,
#     'cloudCover': 0.56,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.23},
#    {'time': 1560285000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 101.52,
#     'apparentTemperature': 101.52,
#     'dewPoint': 52.06,
#     'humidity': 0.19,
#     'pressure': 995.19,
#     'windSpeed': 6.84,
#     'windGust': 6.91,
#     'windBearing': 79,
#     'cloudCover': 0.65,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.24},
#    {'time': 1560288600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 99.87,
#     'apparentTemperature': 99.87,
#     'dewPoint': 53.43,
#     'humidity': 0.21,
#     'pressure': 995.19,
#     'windSpeed': 7.19,
#     'windGust': 7.53,
#     'windBearing': 82,
#     'cloudCover': 0.64,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.34},
#    {'time': 1560292200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 97.83,
#     'apparentTemperature': 97.83,
#     'dewPoint': 55.19,
#     'humidity': 0.24,
#     'pressure': 995.38,
#     'windSpeed': 8.35,
#     'windGust': 11.66,
#     'windBearing': 85,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.55},
#    {'time': 1560295800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 96.09,
#     'apparentTemperature': 96.09,
#     'dewPoint': 57.31,
#     'humidity': 0.28,
#     'pressure': 995.7,
#     'windSpeed': 9.74,
#     'windGust': 17.4,
#     'windBearing': 87,
#     'cloudCover': 0.41,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.65},
#    {'time': 1560299400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 95.61,
#     'apparentTemperature': 95.64,
#     'dewPoint': 59.96,
#     'humidity': 0.31,
#     'pressure': 996.23,
#     'windSpeed': 10.74,
#     'windGust': 19.62,
#     'windBearing': 88,
#     'cloudCover': 0.28,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.64},
#    {'time': 1560303000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 96.19,
#     'apparentTemperature': 97.87,
#     'dewPoint': 63.01,
#     'humidity': 0.34,
#     'pressure': 996.97,
#     'windSpeed': 11.3,
#     'windGust': 18.17,
#     'windBearing': 88,
#     'cloudCover': 0.15,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 287.57},
#    {'time': 1560306600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 98.26,
#     'apparentTemperature': 101.9,
#     'dewPoint': 65.46,
#     'humidity': 0.35,
#     'pressure': 997.65,
#     'windSpeed': 11.55,
#     'windGust': 15.41,
#     'windBearing': 88,
#     'cloudCover': 0.04,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 287.33},
#    {'time': 1560310200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 101.82,
#     'apparentTemperature': 106.99,
#     'dewPoint': 66.42,
#     'humidity': 0.32,
#     'pressure': 997.95,
#     'windSpeed': 11.46,
#     'windGust': 12.91,
#     'windBearing': 89,
#     'cloudCover': 0,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 286.97},
#    {'time': 1560313800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 105.85,
#     'apparentTemperature': 111.64,
#     'dewPoint': 66.03,
#     'humidity': 0.28,
#     'pressure': 997.89,
#     'windSpeed': 11.01,
#     'windGust': 11.27,
#     'windBearing': 91,
#     'cloudCover': 0,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 286.45},
#    {'time': 1560317400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 109.43,
#     'apparentTemperature': 115.1,
#     'dewPoint': 64.98,
#     'humidity': 0.24,
#     'pressure': 997.58,
#     'windSpeed': 10.39,
#     'windGust': 10.4,
#     'windBearing': 91,
#     'cloudCover': 0,
#     'uvIndex': 11,
#     'visibility': 10,
#     'ozone': 285.72},
#    {'time': 1560321000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 111.62,
#     'apparentTemperature': 116.58,
#     'dewPoint': 63.66,
#     'humidity': 0.22,
#     'pressure': 996.98,
#     'windSpeed': 9.72,
#     'windGust': 9.76,
#     'windBearing': 86,
#     'cloudCover': 0,
#     'uvIndex': 12,
#     'visibility': 10,
#     'ozone': 284.73},
#    {'time': 1560324600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 113.25,
#     'apparentTemperature': 117.21,
#     'dewPoint': 62.12,
#     'humidity': 0.2,
#     'pressure': 996.08,
#     'windSpeed': 9.04,
#     'windGust': 9.11,
#     'windBearing': 75,
#     'cloudCover': 0,
#     'uvIndex': 12,
#     'visibility': 10,
#     'ozone': 283.54},
#    {'time': 1560328200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 114.63,
#     'apparentTemperature': 117.6,
#     'dewPoint': 60.63,
#     'humidity': 0.18,
#     'pressure': 995.14,
#     'windSpeed': 8.53,
#     'windGust': 8.58,
#     'windBearing': 63,
#     'cloudCover': 0,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 282.33},
#    {'time': 1560331800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 115.31,
#     'apparentTemperature': 117.58,
#     'dewPoint': 59.6,
#     'humidity': 0.17,
#     'pressure': 994.38,
#     'windSpeed': 8.3,
#     'windGust': 8.32,
#     'windBearing': 54,
#     'cloudCover': 0.06,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 281.3},
#    {'time': 1560335400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 115.32,
#     'apparentTemperature': 117.25,
#     'dewPoint': 59.12,
#     'humidity': 0.17,
#     'pressure': 993.8,
#     'windSpeed': 8.4,
#     'windGust': 8.41,
#     'windBearing': 50,
#     'cloudCover': 0.22,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 280.48},
#    {'time': 1560339000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 114.51,
#     'apparentTemperature': 116.34,
#     'dewPoint': 59,
#     'humidity': 0.17,
#     'pressure': 993.47,
#     'windSpeed': 8.72,
#     'windGust': 8.72,
#     'windBearing': 49,
#     'cloudCover': 0.4,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 279.77},
#    {'time': 1560342600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 113.05,
#     'apparentTemperature': 114.85,
#     'dewPoint': 59.07,
#     'humidity': 0.18,
#     'pressure': 993.56,
#     'windSpeed': 9.03,
#     'windGust': 9.22,
#     'windBearing': 49,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 279.03},
#    {'time': 1560346200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 111.11,
#     'apparentTemperature': 112.89,
#     'dewPoint': 59.26,
#     'humidity': 0.19,
#     'pressure': 994.05,
#     'windSpeed': 9.3,
#     'windGust': 11.1,
#     'windBearing': 51,
#     'cloudCover': 0.75,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 278.23},
#    {'time': 1560349800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 108.93,
#     'apparentTemperature': 110.66,
#     'dewPoint': 59.55,
#     'humidity': 0.2,
#     'pressure': 994.71,
#     'windSpeed': 9.56,
#     'windGust': 13.91,
#     'windBearing': 52,
#     'cloudCover': 0.89,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.58},
#    {'time': 1560353400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 106.97,
#     'apparentTemperature': 108.66,
#     'dewPoint': 59.91,
#     'humidity': 0.22,
#     'pressure': 995.35,
#     'windSpeed': 9.74,
#     'windGust': 15.61,
#     'windBearing': 45,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.26},
#    {'time': 1560357000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 105.26,
#     'apparentTemperature': 106.94,
#     'dewPoint': 60.33,
#     'humidity': 0.23,
#     'pressure': 995.97,
#     'windSpeed': 9.87,
#     'windGust': 16.15,
#     'windBearing': 30,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.28},
#    {'time': 1560360600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0051,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 103.46,
#     'apparentTemperature': 105.12,
#     'dewPoint': 60.79,
#     'humidity': 0.25,
#     'pressure': 996.48,
#     'windSpeed': 10,
#     'windGust': 16.42,
#     'windBearing': 15,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.36},
#    {'time': 1560364200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.007,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 101.35,
#     'apparentTemperature': 102.92,
#     'dewPoint': 61.29,
#     'humidity': 0.27,
#     'pressure': 996.72,
#     'windSpeed': 10.08,
#     'windGust': 17.27,
#     'windBearing': 5,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.55},
#    {'time': 1560367800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0075,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 98.97,
#     'apparentTemperature': 100.44,
#     'dewPoint': 61.83,
#     'humidity': 0.3,
#     'pressure': 996.68,
#     'windSpeed': 9.99,
#     'windGust': 18.72,
#     'windBearing': 3,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.91},
#    {'time': 1560371400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 96.7,
#     'apparentTemperature': 98.07,
#     'dewPoint': 62.33,
#     'humidity': 0.32,
#     'pressure': 996.61,
#     'windSpeed': 9.75,
#     'windGust': 19.66,
#     'windBearing': 3,
#     'cloudCover': 0.94,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 278.17},
#    {'time': 1560375000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0103,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 94.31,
#     'apparentTemperature': 95.5,
#     'dewPoint': 62.61,
#     'humidity': 0.35,
#     'pressure': 996.74,
#     'windSpeed': 9.29,
#     'windGust': 18.71,
#     'windBearing': 4,
#     'cloudCover': 0.91,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 278.04},
#    {'time': 1560378600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0133,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 91.7,
#     'apparentTemperature': 92.64,
#     'dewPoint': 62.69,
#     'humidity': 0.38,
#     'pressure': 997.06,
#     'windSpeed': 8.61,
#     'windGust': 15.85,
#     'windBearing': 7,
#     'cloudCover': 0.87,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 277.52},
#    {'time': 1560382200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0148,
#     'precipProbability': 0.13,
#     'precipType': 'rain',
#     'temperature': 89.71,
#     'apparentTemperature': 90.57,
#     'dewPoint': 62.8,
#     'humidity': 0.41,
#     'pressure': 997.46,
#     'windSpeed': 7.99,
#     'windGust': 12.9,
#     'windBearing': 11,
#     'cloudCover': 0.82,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 276.84},
#    {'time': 1560385800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0111,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 89.48,
#     'apparentTemperature': 90.55,
#     'dewPoint': 63.24,
#     'humidity': 0.42,
#     'pressure': 997.94,
#     'windSpeed': 7.77,
#     'windGust': 11.62,
#     'windBearing': 19,
#     'cloudCover': 0.75,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 276.08},
#    {'time': 1560389400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0044,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 91.37,
#     'apparentTemperature': 93.01,
#     'dewPoint': 64.06,
#     'humidity': 0.41,
#     'pressure': 998.5,
#     'windSpeed': 7.93,
#     'windGust': 12.01,
#     'windBearing': 33,
#     'cloudCover': 0.66,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 275.23},
#    {'time': 1560393000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 94.66,
#     'apparentTemperature': 97.15,
#     'dewPoint': 64.75,
#     'humidity': 0.38,
#     'pressure': 998.95,
#     'windSpeed': 8.2,
#     'windGust': 12.88,
#     'windBearing': 51,
#     'cloudCover': 0.58,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 274.41},
#    {'time': 1560396600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 98.84,
#     'apparentTemperature': 102.1,
#     'dewPoint': 64.73,
#     'humidity': 0.33,
#     'pressure': 999.05,
#     'windSpeed': 8.49,
#     'windGust': 13.44,
#     'windBearing': 74,
#     'cloudCover': 0.49,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 273.85},
#    {'time': 1560400200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 103.87,
#     'apparentTemperature': 107.66,
#     'dewPoint': 64,
#     'humidity': 0.28,
#     'pressure': 998.84,
#     'windSpeed': 8.47,
#     'windGust': 13.68,
#     'windBearing': 102,
#     'cloudCover': 0.4,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 273.46},
#    {'time': 1560403800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 108.34,
#     'apparentTemperature': 112.33,
#     'dewPoint': 63.08,
#     'humidity': 0.24,
#     'pressure': 998.4,
#     'windSpeed': 8.99,
#     'windGust': 13.8,
#     'windBearing': 119,
#     'cloudCover': 0.35,
#     'uvIndex': 9,
#     'visibility': 10,
#     'ozone': 273.16},
#    {'time': 1560407400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 110.97,
#     'apparentTemperature': 114.83,
#     'dewPoint': 62.35,
#     'humidity': 0.21,
#     'pressure': 997.76,
#     'windSpeed': 9.06,
#     'windGust': 13.72,
#     'windBearing': 97,
#     'cloudCover': 0.4,
#     'uvIndex': 10,
#     'visibility': 10,
#     'ozone': 272.85},
#    {'time': 1560411000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 112.41,
#     'apparentTemperature': 116.03,
#     'dewPoint': 61.79,
#     'humidity': 0.2,
#     'pressure': 996.92,
#     'windSpeed': 10.14,
#     'windGust': 13.45,
#     'windBearing': 62,
#     'cloudCover': 0.54,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 272.54},
#    {'time': 1560414600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 113.05,
#     'apparentTemperature': 116.38,
#     'dewPoint': 61.29,
#     'humidity': 0.19,
#     'pressure': 996.06,
#     'windSpeed': 10.82,
#     'windGust': 13.2,
#     'windBearing': 39,
#     'cloudCover': 0.69,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 272.22},
#    {'time': 1560418200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 112.93,
#     'apparentTemperature': 115.84,
#     'dewPoint': 60.73,
#     'humidity': 0.19,
#     'pressure': 995.37,
#     'windSpeed': 11.35,
#     'windGust': 13.1,
#     'windBearing': 25,
#     'cloudCover': 0.8,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 271.91},
#    {'time': 1560421800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 112.32,
#     'apparentTemperature': 114.74,
#     'dewPoint': 60.09,
#     'humidity': 0.19,
#     'pressure': 994.83,
#     'windSpeed': 12.01,
#     'windGust': 13.18,
#     'windBearing': 14,
#     'cloudCover': 0.84,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 271.62},
#    {'time': 1560425400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0027,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 111.03,
#     'apparentTemperature': 113.07,
#     'dewPoint': 59.69,
#     'humidity': 0.19,
#     'pressure': 994.53,
#     'windSpeed': 12.31,
#     'windGust': 13.64,
#     'windBearing': 7,
#     'cloudCover': 0.85,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 271.46}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures falling to 105°F next Tuesday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560191400,
#     'summary': 'Partly cloudy overnight.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560210522,
#     'sunsetTime': 1560259908,
#     'moonPhase': 0.29,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1560249000,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperatureHigh': 117.28,
#     'temperatureHighTime': 1560241800,
#     'temperatureLow': 95.61,
#     'temperatureLowTime': 1560299400,
#     'apparentTemperatureHigh': 117.28,
#     'apparentTemperatureHighTime': 1560241800,
#     'apparentTemperatureLow': 95.64,
#     'apparentTemperatureLowTime': 1560299400,
#     'dewPoint': 52.75,
#     'humidity': 0.19,
#     'pressure': 995.01,
#     'windSpeed': 4.93,
#     'windGust': 17.52,
#     'windGustTime': 1560209400,
#     'windBearing': 56,
#     'cloudCover': 0.12,
#     'uvIndex': 12,
#     'uvIndexTime': 1560234600,
#     'visibility': 10,
#     'ozone': 287.83,
#     'temperatureMin': 90.49,
#     'temperatureMinTime': 1560205800,
#     'temperatureMax': 117.28,
#     'temperatureMaxTime': 1560241800,
#     'apparentTemperatureMin': 90.49,
#     'apparentTemperatureMinTime': 1560205800,
#     'apparentTemperatureMax': 117.28,
#     'apparentTemperatureMaxTime': 1560241800},
#    {'time': 1560277800,
#     'summary': 'Mostly cloudy starting in the evening.',
#     'icon': 'partly-cloudy-night',
#     'sunriseTime': 1560296924,
#     'sunsetTime': 1560346329,
#     'moonPhase': 0.33,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0051,
#     'precipIntensityMaxTime': 1560360600,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 115.32,
#     'temperatureHighTime': 1560335400,
#     'temperatureLow': 89.48,
#     'temperatureLowTime': 1560385800,
#     'apparentTemperatureHigh': 117.6,
#     'apparentTemperatureHighTime': 1560328200,
#     'apparentTemperatureLow': 90.55,
#     'apparentTemperatureLowTime': 1560385800,
#     'dewPoint': 59.51,
#     'humidity': 0.23,
#     'pressure': 995.69,
#     'windSpeed': 8.67,
#     'windGust': 19.62,
#     'windGustTime': 1560299400,
#     'windBearing': 69,
#     'cloudCover': 0.4,
#     'uvIndex': 12,
#     'uvIndexTime': 1560321000,
#     'visibility': 10,
#     'ozone': 283.54,
#     'temperatureMin': 95.61,
#     'temperatureMinTime': 1560299400,
#     'temperatureMax': 115.32,
#     'temperatureMaxTime': 1560335400,
#     'apparentTemperatureMin': 95.64,
#     'apparentTemperatureMinTime': 1560299400,
#     'apparentTemperatureMax': 117.6,
#     'apparentTemperatureMaxTime': 1560328200},
#    {'time': 1560364200,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560383327,
#     'sunsetTime': 1560432750,
#     'moonPhase': 0.36,
#     'precipIntensity': 0.0036,
#     'precipIntensityMax': 0.0148,
#     'precipIntensityMaxTime': 1560382200,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperatureHigh': 113.05,
#     'temperatureHighTime': 1560414600,
#     'temperatureLow': 91.42,
#     'temperatureLowTime': 1560468600,
#     'apparentTemperatureHigh': 116.38,
#     'apparentTemperatureHighTime': 1560414600,
#     'apparentTemperatureLow': 93.19,
#     'apparentTemperatureLowTime': 1560468600,
#     'dewPoint': 62.39,
#     'humidity': 0.29,
#     'pressure': 996.9,
#     'windSpeed': 6.69,
#     'windGust': 20.28,
#     'windGustTime': 1560439800,
#     'windBearing': 34,
#     'cloudCover': 0.71,
#     'uvIndex': 10,
#     'uvIndexTime': 1560407400,
#     'visibility': 10,
#     'ozone': 274.17,
#     'temperatureMin': 89.48,
#     'temperatureMinTime': 1560385800,
#     'temperatureMax': 113.05,
#     'temperatureMaxTime': 1560414600,
#     'apparentTemperatureMin': 90.55,
#     'apparentTemperatureMinTime': 1560385800,
#     'apparentTemperatureMax': 116.38,
#     'apparentTemperatureMaxTime': 1560414600},
#    {'time': 1560450600,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560469731,
#     'sunsetTime': 1560519169,
#     'moonPhase': 0.4,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560511800,
#     'precipProbability': 0,
#     'temperatureHigh': 114.95,
#     'temperatureHighTime': 1560508200,
#     'temperatureLow': 94.18,
#     'temperatureLowTime': 1560555000,
#     'apparentTemperatureHigh': 114.95,
#     'apparentTemperatureHighTime': 1560508200,
#     'apparentTemperatureLow': 94.6,
#     'apparentTemperatureLowTime': 1560555000,
#     'dewPoint': 60.07,
#     'humidity': 0.27,
#     'pressure': 995.64,
#     'windSpeed': 8.2,
#     'windGust': 27.38,
#     'windGustTime': 1560479400,
#     'windBearing': 292,
#     'cloudCover': 0.68,
#     'uvIndex': 8,
#     'uvIndexTime': 1560497400,
#     'visibility': 10,
#     'ozone': 275.09,
#     'temperatureMin': 91.42,
#     'temperatureMinTime': 1560468600,
#     'temperatureMax': 114.95,
#     'temperatureMaxTime': 1560508200,
#     'apparentTemperatureMin': 93.19,
#     'apparentTemperatureMinTime': 1560468600,
#     'apparentTemperatureMax': 114.95,
#     'apparentTemperatureMaxTime': 1560508200},
#    {'time': 1560537000,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560556136,
#     'sunsetTime': 1560605588,
#     'moonPhase': 0.43,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560544200,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 114.13,
#     'temperatureHighTime': 1560591000,
#     'temperatureLow': 91.53,
#     'temperatureLowTime': 1560641400,
#     'apparentTemperatureHigh': 114.3,
#     'apparentTemperatureHighTime': 1560583800,
#     'apparentTemperatureLow': 92.74,
#     'apparentTemperatureLowTime': 1560637800,
#     'dewPoint': 57.96,
#     'humidity': 0.23,
#     'pressure': 994.53,
#     'windSpeed': 8.4,
#     'windGust': 29.43,
#     'windGustTime': 1560558600,
#     'windBearing': 290,
#     'cloudCover': 0.38,
#     'uvIndex': 10,
#     'uvIndexTime': 1560580200,
#     'visibility': 10,
#     'ozone': 273.47,
#     'temperatureMin': 94.18,
#     'temperatureMinTime': 1560555000,
#     'temperatureMax': 114.13,
#     'temperatureMaxTime': 1560591000,
#     'apparentTemperatureMin': 94.6,
#     'apparentTemperatureMinTime': 1560555000,
#     'apparentTemperatureMax': 114.3,
#     'apparentTemperatureMaxTime': 1560583800},
#    {'time': 1560623400,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560642542,
#     'sunsetTime': 1560692006,
#     'moonPhase': 0.47,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1560702600,
#     'precipProbability': 0,
#     'temperatureHigh': 114.81,
#     'temperatureHighTime': 1560673800,
#     'temperatureLow': 96.08,
#     'temperatureLowTime': 1560720600,
#     'apparentTemperatureHigh': 117.16,
#     'apparentTemperatureHighTime': 1560677400,
#     'apparentTemperatureLow': 96.08,
#     'apparentTemperatureLowTime': 1560720600,
#     'dewPoint': 59.31,
#     'humidity': 0.24,
#     'pressure': 994.38,
#     'windSpeed': 11.39,
#     'windGust': 28.4,
#     'windGustTime': 1560634200,
#     'windBearing': 289,
#     'cloudCover': 0.6,
#     'uvIndex': 9,
#     'uvIndexTime': 1560663000,
#     'visibility': 10,
#     'ozone': 271.51,
#     'temperatureMin': 91.53,
#     'temperatureMinTime': 1560641400,
#     'temperatureMax': 114.81,
#     'temperatureMaxTime': 1560673800,
#     'apparentTemperatureMin': 92.74,
#     'apparentTemperatureMinTime': 1560637800,
#     'apparentTemperatureMax': 117.16,
#     'apparentTemperatureMaxTime': 1560677400},
#    {'time': 1560709800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560728950,
#     'sunsetTime': 1560778423,
#     'moonPhase': 0.51,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1560709800,
#     'precipProbability': 0,
#     'temperatureHigh': 111.66,
#     'temperatureHighTime': 1560760200,
#     'temperatureLow': 87.11,
#     'temperatureLowTime': 1560814200,
#     'apparentTemperatureHigh': 114.5,
#     'apparentTemperatureHighTime': 1560756600,
#     'apparentTemperatureLow': 91.25,
#     'apparentTemperatureLowTime': 1560814200,
#     'dewPoint': 59.7,
#     'humidity': 0.24,
#     'pressure': 994.78,
#     'windSpeed': 9.69,
#     'windGust': 26.31,
#     'windGustTime': 1560720600,
#     'windBearing': 280,
#     'cloudCover': 0.61,
#     'uvIndex': 9,
#     'uvIndexTime': 1560749400,
#     'visibility': 10,
#     'ozone': 274.24,
#     'temperatureMin': 96.08,
#     'temperatureMinTime': 1560720600,
#     'temperatureMax': 111.66,
#     'temperatureMaxTime': 1560760200,
#     'apparentTemperatureMin': 96.08,
#     'apparentTemperatureMinTime': 1560720600,
#     'apparentTemperatureMax': 114.5,
#     'apparentTemperatureMaxTime': 1560756600},
#    {'time': 1560796200,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1560815358,
#     'sunsetTime': 1560864839,
#     'moonPhase': 0.53,
#     'precipIntensity': 0.0044,
#     'precipIntensityMax': 0.0185,
#     'precipIntensityMaxTime': 1560810600,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperatureHigh': 105.29,
#     'temperatureHighTime': 1560857400,
#     'temperatureLow': 91.18,
#     'temperatureLowTime': 1560900600,
#     'apparentTemperatureHigh': 111.95,
#     'apparentTemperatureHighTime': 1560853800,
#     'apparentTemperatureLow': 95.23,
#     'apparentTemperatureLowTime': 1560900600,
#     'dewPoint': 68.04,
#     'humidity': 0.4,
#     'pressure': 995.41,
#     'windSpeed': 9.28,
#     'windGust': 23.13,
#     'windGustTime': 1560821400,
#     'windBearing': 265,
#     'cloudCover': 0.96,
#     'uvIndex': 5,
#     'uvIndexTime': 1560832200,
#     'visibility': 10,
#     'ozone': 274.62,
#     'temperatureMin': 87.11,
#     'temperatureMinTime': 1560814200,
#     'temperatureMax': 105.29,
#     'temperatureMaxTime': 1560857400,
#     'apparentTemperatureMin': 91.25,
#     'apparentTemperatureMinTime': 1560814200,
#     'apparentTemperatureMax': 111.95,
#     'apparentTemperatureMaxTime': 1560853800}]},
#  'flags': {'sources': ['cmc', 'gfs', 'icon', 'isd', 'madis'], 'units': 'us'},
#  'offset': 5.5}

# %%
response2 = requests.get('https://api.darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/25.7776,-80.2192?units=si')
#https://darksky.net/forecast/c5b60f33dabc56e73a39cae44466db42/25.7776,-80.2192
data_miami = response2.json()
data_miami
# Out:
# {'latitude': 25.7776,
#  'longitude': -80.2192,
#  'timezone': 'America/New_York',
#  'currently': {'time': 1560256141,
#   'summary': 'Humid',
#   'icon': 'clear-day',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.127,
#   'precipIntensityError': 0.1016,
#   'precipProbability': 0.1,
#   'precipType': 'rain',
#   'temperature': 26.68,
#   'apparentTemperature': 29.06,
#   'dewPoint': 22.97,
#   'humidity': 0.8,
#   'pressure': 1017.12,
#   'windSpeed': 0.37,
#   'windGust': 0.54,
#   'windBearing': 222,
#   'cloudCover': 0.06,
#   'uvIndex': 1,
#   'visibility': 16.09,
#   'ozone': 291.15},
#  'minutely': {'summary': 'Humid for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1560256140,
#     'precipIntensity': 0.127,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1560256200,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.09,
#     'precipType': 'rain'},
#    {'time': 1560256260,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1560256320,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.0762,
#     'precipProbability': 0.06,
#     'precipType': 'rain'},
#    {'time': 1560256380,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.05,
#     'precipType': 'rain'},
#    {'time': 1560256440,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560256500,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560256560,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.04,
#     'precipType': 'rain'},
#    {'time': 1560256620,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560256680,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.0762,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560256740,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.03,
#     'precipType': 'rain'},
#    {'time': 1560256800,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560256860,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560256920,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560256980,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.127,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560257040,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.02,
#     'precipType': 'rain'},
#    {'time': 1560257100,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257160,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257220,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257280,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257340,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257400,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257460,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.0762,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257520,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257580,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560257700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560257760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560257820,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.0762,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560257880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560257940,
#     'precipIntensity': 0.1778,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560258000,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.0762,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560258060,
#     'precipIntensity': 0.1524,
#     'precipIntensityError': 0.1016,
#     'precipProbability': 0.01,
#     'precipType': 'rain'},
#    {'time': 1560258120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560258960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1560259740, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Humid throughout the day and partly cloudy until tomorrow morning.',
#   'icon': 'partly-cloudy-night',
#   'data': [{'time': 1560254400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0229,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 25.9,
#     'apparentTemperature': 27.61,
#     'dewPoint': 23.01,
#     'humidity': 0.84,
#     'pressure': 1016.97,
#     'windSpeed': 0.35,
#     'windGust': 0.42,
#     'windBearing': 266,
#     'cloudCover': 0.06,
#     'uvIndex': 1,
#     'visibility': 16.09,
#     'ozone': 290.83},
#    {'time': 1560258000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0737,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 27.51,
#     'apparentTemperature': 30.41,
#     'dewPoint': 22.87,
#     'humidity': 0.76,
#     'pressure': 1017.28,
#     'windSpeed': 0.56,
#     'windGust': 0.67,
#     'windBearing': 194,
#     'cloudCover': 0.07,
#     'uvIndex': 2,
#     'visibility': 16.09,
#     'ozone': 291.49},
#    {'time': 1560261600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0076,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 29.71,
#     'apparentTemperature': 33.61,
#     'dewPoint': 22.83,
#     'humidity': 0.67,
#     'pressure': 1017.54,
#     'windSpeed': 1.58,
#     'windGust': 1.7,
#     'windBearing': 176,
#     'cloudCover': 0.23,
#     'uvIndex': 5,
#     'visibility': 16.09,
#     'ozone': 291.99},
#    {'time': 1560265200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0102,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 31.21,
#     'apparentTemperature': 35.56,
#     'dewPoint': 22.77,
#     'humidity': 0.61,
#     'pressure': 1017.59,
#     'windSpeed': 2.41,
#     'windGust': 2.7,
#     'windBearing': 168,
#     'cloudCover': 0.32,
#     'uvIndex': 7,
#     'visibility': 16.09,
#     'ozone': 292.46},
#    {'time': 1560268800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 31.81,
#     'apparentTemperature': 36.19,
#     'dewPoint': 22.63,
#     'humidity': 0.58,
#     'pressure': 1017.34,
#     'windSpeed': 3.04,
#     'windGust': 3.38,
#     'windBearing': 161,
#     'cloudCover': 0.33,
#     'uvIndex': 9,
#     'visibility': 16.09,
#     'ozone': 292.47},
#    {'time': 1560272400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 32.5,
#     'apparentTemperature': 37.02,
#     'dewPoint': 22.59,
#     'humidity': 0.56,
#     'pressure': 1017.05,
#     'windSpeed': 3.73,
#     'windGust': 3.91,
#     'windBearing': 154,
#     'cloudCover': 0.36,
#     'uvIndex': 9,
#     'visibility': 16.09,
#     'ozone': 292.35},
#    {'time': 1560276000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0178,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 32.82,
#     'apparentTemperature': 37.53,
#     'dewPoint': 22.68,
#     'humidity': 0.55,
#     'pressure': 1016.65,
#     'windSpeed': 4.39,
#     'windGust': 4.64,
#     'windBearing': 152,
#     'cloudCover': 0.37,
#     'uvIndex': 9,
#     'visibility': 16.09,
#     'ozone': 292.14},
#    {'time': 1560279600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 33.09,
#     'apparentTemperature': 37.95,
#     'dewPoint': 22.76,
#     'humidity': 0.55,
#     'pressure': 1016.07,
#     'windSpeed': 4.82,
#     'windGust': 5.35,
#     'windBearing': 151,
#     'cloudCover': 0.32,
#     'uvIndex': 8,
#     'visibility': 16.09,
#     'ozone': 291.78},
#    {'time': 1560283200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0229,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 32.77,
#     'apparentTemperature': 37.61,
#     'dewPoint': 22.82,
#     'humidity': 0.56,
#     'pressure': 1015.69,
#     'windSpeed': 5.02,
#     'windGust': 5.83,
#     'windBearing': 158,
#     'cloudCover': 0.31,
#     'uvIndex': 6,
#     'visibility': 16.09,
#     'ozone': 291.22},
#    {'time': 1560286800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0381,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 32.09,
#     'apparentTemperature': 36.86,
#     'dewPoint': 22.93,
#     'humidity': 0.59,
#     'pressure': 1015.24,
#     'windSpeed': 4.71,
#     'windGust': 5.53,
#     'windBearing': 166,
#     'cloudCover': 0.28,
#     'uvIndex': 4,
#     'visibility': 16.09,
#     'ozone': 291.4},
#    {'time': 1560290400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.066,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 31.16,
#     'apparentTemperature': 35.77,
#     'dewPoint': 23.06,
#     'humidity': 0.62,
#     'pressure': 1015.1,
#     'windSpeed': 4.82,
#     'windGust': 5.96,
#     'windBearing': 163,
#     'cloudCover': 0.34,
#     'uvIndex': 2,
#     'visibility': 16.09,
#     'ozone': 292.58},
#    {'time': 1560294000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0203,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 30.28,
#     'apparentTemperature': 34.66,
#     'dewPoint': 23.12,
#     'humidity': 0.66,
#     'pressure': 1015.27,
#     'windSpeed': 4.6,
#     'windGust': 5.97,
#     'windBearing': 167,
#     'cloudCover': 0.33,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 294.3},
#    {'time': 1560297600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0457,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 29.42,
#     'apparentTemperature': 33.52,
#     'dewPoint': 23.19,
#     'humidity': 0.69,
#     'pressure': 1015.62,
#     'windSpeed': 4.17,
#     'windGust': 5.51,
#     'windBearing': 172,
#     'cloudCover': 0.31,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 295.93},
#    {'time': 1560301200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0178,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 28.93,
#     'apparentTemperature': 32.84,
#     'dewPoint': 23.22,
#     'humidity': 0.71,
#     'pressure': 1016.13,
#     'windSpeed': 3.77,
#     'windGust': 5.23,
#     'windBearing': 179,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 297.43},
#    {'time': 1560304800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0203,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 28.65,
#     'apparentTemperature': 32.29,
#     'dewPoint': 23.06,
#     'humidity': 0.72,
#     'pressure': 1016.39,
#     'windSpeed': 3.66,
#     'windGust': 4.63,
#     'windBearing': 177,
#     'cloudCover': 0.29,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 298.9},
#    {'time': 1560308400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0254,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 28.14,
#     'apparentTemperature': 31.53,
#     'dewPoint': 23.09,
#     'humidity': 0.74,
#     'pressure': 1016.84,
#     'windSpeed': 3.31,
#     'windGust': 4.17,
#     'windBearing': 180,
#     'cloudCover': 0.23,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 299.94},
#    {'time': 1560312000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0279,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 27.76,
#     'apparentTemperature': 30.94,
#     'dewPoint': 23.09,
#     'humidity': 0.76,
#     'pressure': 1016.77,
#     'windSpeed': 2.98,
#     'windGust': 3.62,
#     'windBearing': 185,
#     'cloudCover': 0.17,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 300.17},
#    {'time': 1560315600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0279,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 27.43,
#     'apparentTemperature': 30.38,
#     'dewPoint': 23.07,
#     'humidity': 0.77,
#     'pressure': 1016.39,
#     'windSpeed': 2.68,
#     'windGust': 3.01,
#     'windBearing': 188,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 300.03},
#    {'time': 1560319200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0229,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 27.18,
#     'apparentTemperature': 29.97,
#     'dewPoint': 23.04,
#     'humidity': 0.78,
#     'pressure': 1016.05,
#     'windSpeed': 2.43,
#     'windGust': 2.53,
#     'windBearing': 191,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 300.23},
#    {'time': 1560322800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0127,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 26.85,
#     'apparentTemperature': 29.36,
#     'dewPoint': 22.97,
#     'humidity': 0.79,
#     'pressure': 1015.82,
#     'windSpeed': 2.27,
#     'windGust': 2.28,
#     'windBearing': 191,
#     'cloudCover': 0.28,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 301.2},
#    {'time': 1560326400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.63,
#     'apparentTemperature': 28.96,
#     'dewPoint': 22.91,
#     'humidity': 0.8,
#     'pressure': 1015.58,
#     'windSpeed': 2.15,
#     'windGust': 2.16,
#     'windBearing': 189,
#     'cloudCover': 0.52,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 302.51},
#    {'time': 1560330000,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.44,
#     'apparentTemperature': 28.59,
#     'dewPoint': 22.84,
#     'humidity': 0.81,
#     'pressure': 1015.51,
#     'windSpeed': 2.07,
#     'windGust': 2.08,
#     'windBearing': 187,
#     'cloudCover': 0.68,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 303.7},
#    {'time': 1560333600,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.74,
#     'apparentTemperature': 29.12,
#     'dewPoint': 22.84,
#     'humidity': 0.79,
#     'pressure': 1015.67,
#     'windSpeed': 2.02,
#     'windGust': 2.03,
#     'windBearing': 183,
#     'cloudCover': 0.68,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 304.39},
#    {'time': 1560337200,
#     'summary': 'Humid and Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0127,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 27.31,
#     'apparentTemperature': 30.09,
#     'dewPoint': 22.88,
#     'humidity': 0.77,
#     'pressure': 1015.98,
#     'windSpeed': 2.01,
#     'windGust': 2.02,
#     'windBearing': 179,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 305.01},
#    {'time': 1560340800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0203,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 28.11,
#     'apparentTemperature': 31.36,
#     'dewPoint': 22.89,
#     'humidity': 0.73,
#     'pressure': 1016.33,
#     'windSpeed': 2.13,
#     'windGust': 2.14,
#     'windBearing': 175,
#     'cloudCover': 0.54,
#     'uvIndex': 1,
#     'visibility': 16.09,
#     'ozone': 305.46},
#    {'time': 1560344400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0127,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 29.29,
#     'apparentTemperature': 33.06,
#     'dewPoint': 22.84,
#     'humidity': 0.68,
#     'pressure': 1016.79,
#     'windSpeed': 2.43,
#     'windGust': 2.44,
#     'windBearing': 173,
#     'cloudCover': 0.54,
#     'uvIndex': 2,
#     'visibility': 16.09,
#     'ozone': 305.62},
#    {'time': 1560348000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0051,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 30.44,
#     'apparentTemperature': 34.53,
#     'dewPoint': 22.75,
#     'humidity': 0.64,
#     'pressure': 1017.28,
#     'windSpeed': 2.84,
#     'windGust': 2.84,
#     'windBearing': 170,
#     'cloudCover': 0.52,
#     'uvIndex': 4,
#     'visibility': 16.09,
#     'ozone': 305.79},
#    {'time': 1560351600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 31.2,
#     'apparentTemperature': 35.43,
#     'dewPoint': 22.66,
#     'humidity': 0.61,
#     'pressure': 1017.57,
#     'windSpeed': 3.25,
#     'windGust': 3.25,
#     'windBearing': 167,
#     'cloudCover': 0.5,
#     'uvIndex': 6,
#     'visibility': 16.09,
#     'ozone': 305.93},
#    {'time': 1560355200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0152,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 31.84,
#     'apparentTemperature': 36.16,
#     'dewPoint': 22.55,
#     'humidity': 0.58,
#     'pressure': 1017.57,
#     'windSpeed': 3.68,
#     'windGust': 3.69,
#     'windBearing': 163,
#     'cloudCover': 0.47,
#     'uvIndex': 7,
#     'visibility': 16.09,
#     'ozone': 306.14},
#    {'time': 1560358800,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0457,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 32.56,
#     'apparentTemperature': 36.97,
#     'dewPoint': 22.46,
#     'humidity': 0.55,
#     'pressure': 1017.35,
#     'windSpeed': 4.15,
#     'windGust': 4.15,
#     'windBearing': 158,
#     'cloudCover': 0.43,
#     'uvIndex': 8,
#     'visibility': 16.09,
#     'ozone': 306.25},
#    {'time': 1560362400,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0686,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 32.96,
#     'apparentTemperature': 37.44,
#     'dewPoint': 22.43,
#     'humidity': 0.54,
#     'pressure': 1017.04,
#     'windSpeed': 4.55,
#     'windGust': 4.56,
#     'windBearing': 155,
#     'cloudCover': 0.38,
#     'uvIndex': 9,
#     'visibility': 16.09,
#     'ozone': 306.16},
#    {'time': 1560366000,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0508,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 33.16,
#     'apparentTemperature': 37.8,
#     'dewPoint': 22.53,
#     'humidity': 0.54,
#     'pressure': 1016.55,
#     'windSpeed': 4.91,
#     'windGust': 4.91,
#     'windBearing': 157,
#     'cloudCover': 0.27,
#     'uvIndex': 8,
#     'visibility': 16.09,
#     'ozone': 305.75},
#    {'time': 1560369600,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0356,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 32.88,
#     'apparentTemperature': 37.61,
#     'dewPoint': 22.69,
#     'humidity': 0.55,
#     'pressure': 1016,
#     'windSpeed': 5.18,
#     'windGust': 5.18,
#     'windBearing': 160,
#     'cloudCover': 0.13,
#     'uvIndex': 6,
#     'visibility': 16.09,
#     'ozone': 305.23},
#    {'time': 1560373200,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0406,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 32.21,
#     'apparentTemperature': 36.94,
#     'dewPoint': 22.87,
#     'humidity': 0.58,
#     'pressure': 1015.63,
#     'windSpeed': 5.28,
#     'windGust': 5.37,
#     'windBearing': 165,
#     'cloudCover': 0.04,
#     'uvIndex': 4,
#     'visibility': 16.09,
#     'ozone': 304.43},
#    {'time': 1560376800,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0584,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 31.27,
#     'apparentTemperature': 35.91,
#     'dewPoint': 23.05,
#     'humidity': 0.62,
#     'pressure': 1015.59,
#     'windSpeed': 5.12,
#     'windGust': 5.63,
#     'windBearing': 170,
#     'cloudCover': 0.04,
#     'uvIndex': 2,
#     'visibility': 16.09,
#     'ozone': 303.67},
#    {'time': 1560380400,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.1422,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 30.38,
#     'apparentTemperature': 34.91,
#     'dewPoint': 23.24,
#     'humidity': 0.66,
#     'pressure': 1015.73,
#     'windSpeed': 4.81,
#     'windGust': 5.74,
#     'windBearing': 175,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 302.69},
#    {'time': 1560384000,
#     'summary': 'Humid',
#     'icon': 'clear-day',
#     'precipIntensity': 0.2311,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 29.57,
#     'apparentTemperature': 33.91,
#     'dewPoint': 23.38,
#     'humidity': 0.69,
#     'pressure': 1016.01,
#     'windSpeed': 4.39,
#     'windGust': 5.6,
#     'windBearing': 180,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 301.62},
#    {'time': 1560387600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.2032,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 29.19,
#     'apparentTemperature': 33.41,
#     'dewPoint': 23.44,
#     'humidity': 0.71,
#     'pressure': 1016.49,
#     'windSpeed': 3.8,
#     'windGust': 4.97,
#     'windBearing': 184,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 300.3},
#    {'time': 1560391200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.1422,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 28.71,
#     'apparentTemperature': 32.69,
#     'dewPoint': 23.47,
#     'humidity': 0.73,
#     'pressure': 1017.08,
#     'windSpeed': 3.11,
#     'windGust': 4.06,
#     'windBearing': 188,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 298.85},
#    {'time': 1560394800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.1016,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 28.28,
#     'apparentTemperature': 32.02,
#     'dewPoint': 23.47,
#     'humidity': 0.75,
#     'pressure': 1017.47,
#     'windSpeed': 2.65,
#     'windGust': 3.42,
#     'windBearing': 195,
#     'cloudCover': 0.15,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 297.53},
#    {'time': 1560398400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0533,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 27.98,
#     'apparentTemperature': 31.52,
#     'dewPoint': 23.46,
#     'humidity': 0.77,
#     'pressure': 1017.49,
#     'windSpeed': 2.62,
#     'windGust': 3.34,
#     'windBearing': 200,
#     'cloudCover': 0.18,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 296.51},
#    {'time': 1560402000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0127,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 27.81,
#     'apparentTemperature': 31.21,
#     'dewPoint': 23.41,
#     'humidity': 0.77,
#     'pressure': 1017.3,
#     'windSpeed': 2.81,
#     'windGust': 3.49,
#     'windBearing': 207,
#     'cloudCover': 0.21,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 295.63},
#    {'time': 1560405600,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 27.58,
#     'apparentTemperature': 30.8,
#     'dewPoint': 23.37,
#     'humidity': 0.78,
#     'pressure': 1017.08,
#     'windSpeed': 2.93,
#     'windGust': 3.56,
#     'windBearing': 214,
#     'cloudCover': 0.22,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 294.83},
#    {'time': 1560409200,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 27.36,
#     'apparentTemperature': 30.39,
#     'dewPoint': 23.29,
#     'humidity': 0.79,
#     'pressure': 1016.84,
#     'windSpeed': 2.86,
#     'windGust': 3.46,
#     'windBearing': 226,
#     'cloudCover': 0.19,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 294.03},
#    {'time': 1560412800,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.99,
#     'apparentTemperature': 29.71,
#     'dewPoint': 23.21,
#     'humidity': 0.8,
#     'pressure': 1016.56,
#     'windSpeed': 2.72,
#     'windGust': 3.25,
#     'windBearing': 236,
#     'cloudCover': 0.13,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 293.25},
#    {'time': 1560416400,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.64,
#     'apparentTemperature': 29.04,
#     'dewPoint': 23.13,
#     'humidity': 0.81,
#     'pressure': 1016.5,
#     'windSpeed': 2.53,
#     'windGust': 2.95,
#     'windBearing': 232,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 292.55},
#    {'time': 1560420000,
#     'summary': 'Humid',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.66,
#     'apparentTemperature': 29.07,
#     'dewPoint': 23.09,
#     'humidity': 0.81,
#     'pressure': 1016.75,
#     'windSpeed': 2.25,
#     'windGust': 2.44,
#     'windBearing': 201,
#     'cloudCover': 0.19,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 291.77},
#    {'time': 1560423600,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 26.98,
#     'apparentTemperature': 29.61,
#     'dewPoint': 23.04,
#     'humidity': 0.79,
#     'pressure': 1017.17,
#     'windSpeed': 1.91,
#     'windGust': 1.93,
#     'windBearing': 275,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 16.09,
#     'ozone': 291},
#    {'time': 1560427200,
#     'summary': 'Humid and Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 27.79,
#     'apparentTemperature': 30.91,
#     'dewPoint': 22.96,
#     'humidity': 0.75,
#     'pressure': 1017.57,
#     'windSpeed': 1.68,
#     'windGust': 1.68,
#     'windBearing': 252,
#     'cloudCover': 0.36,
#     'uvIndex': 1,
#     'visibility': 16.09,
#     'ozone': 290.52}]},
#  'daily': {'summary': 'Rain on Thursday through next Tuesday, with high temperatures falling to 30°C on Monday.',
#   'icon': 'rain',
#   'data': [{'time': 1560225600,
#     'summary': 'Humid and partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560249019,
#     'sunsetTime': 1560298418,
#     'moonPhase': 0.3,
#     'precipIntensity': 0.0229,
#     'precipIntensityMax': 0.0737,
#     'precipIntensityMaxTime': 1560258000,
#     'precipProbability': 0.22,
#     'precipType': 'rain',
#     'temperatureHigh': 33.09,
#     'temperatureHighTime': 1560279600,
#     'temperatureLow': 26.44,
#     'temperatureLowTime': 1560330000,
#     'apparentTemperatureHigh': 37.95,
#     'apparentTemperatureHighTime': 1560279600,
#     'apparentTemperatureLow': 28.59,
#     'apparentTemperatureLowTime': 1560330000,
#     'dewPoint': 23.02,
#     'humidity': 0.72,
#     'pressure': 1016.44,
#     'windSpeed': 2.36,
#     'windGust': 5.97,
#     'windGustTime': 1560294000,
#     'windBearing': 170,
#     'cloudCover': 0.19,
#     'uvIndex': 9,
#     'uvIndexTime': 1560268800,
#     'visibility': 16.09,
#     'ozone': 292.58,
#     'temperatureMin': 24.94,
#     'temperatureMinTime': 1560243600,
#     'temperatureMax': 33.09,
#     'temperatureMaxTime': 1560279600,
#     'apparentTemperatureMin': 25.82,
#     'apparentTemperatureMinTime': 1560250800,
#     'apparentTemperatureMax': 37.95,
#     'apparentTemperatureMaxTime': 1560279600},
#    {'time': 1560312000,
#     'summary': 'Humid throughout the day and partly cloudy until afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560335422,
#     'sunsetTime': 1560384839,
#     'moonPhase': 0.34,
#     'precipIntensity': 0.0533,
#     'precipIntensityMax': 0.2311,
#     'precipIntensityMaxTime': 1560384000,
#     'precipProbability': 0.26,
#     'precipType': 'rain',
#     'temperatureHigh': 33.16,
#     'temperatureHighTime': 1560366000,
#     'temperatureLow': 26.64,
#     'temperatureLowTime': 1560416400,
#     'apparentTemperatureHigh': 37.8,
#     'apparentTemperatureHighTime': 1560366000,
#     'apparentTemperatureLow': 29.04,
#     'apparentTemperatureLowTime': 1560416400,
#     'dewPoint': 22.93,
#     'humidity': 0.69,
#     'pressure': 1016.43,
#     'windSpeed': 3.29,
#     'windGust': 5.74,
#     'windGustTime': 1560380400,
#     'windBearing': 173,
#     'cloudCover': 0.32,
#     'uvIndex': 9,
#     'uvIndexTime': 1560362400,
#     'visibility': 16.09,
#     'ozone': 303.28,
#     'temperatureMin': 26.44,
#     'temperatureMinTime': 1560330000,
#     'temperatureMax': 33.16,
#     'temperatureMaxTime': 1560366000,
#     'apparentTemperatureMin': 28.59,
#     'apparentTemperatureMinTime': 1560330000,
#     'apparentTemperatureMax': 37.8,
#     'apparentTemperatureMaxTime': 1560366000},
#    {'time': 1560398400,
#     'summary': 'Heavy rain starting in the afternoon.',
#     'icon': 'rain',
#     'sunriseTime': 1560421825,
#     'sunsetTime': 1560471259,
#     'moonPhase': 0.38,
#     'precipIntensity': 1.4453,
#     'precipIntensityMax': 11.176,
#     'precipIntensityMaxTime': 1560470400,
#     'precipProbability': 0.68,
#     'precipType': 'rain',
#     'temperatureHigh': 32.88,
#     'temperatureHighTime': 1560456000,
#     'temperatureLow': 25.97,
#     'temperatureLowTime': 1560502800,
#     'apparentTemperatureHigh': 37.78,
#     'apparentTemperatureHighTime': 1560456000,
#     'apparentTemperatureLow': 27.79,
#     'apparentTemperatureLowTime': 1560502800,
#     'dewPoint': 22.94,
#     'humidity': 0.69,
#     'pressure': 1017.28,
#     'windSpeed': 2.35,
#     'windGust': 5.54,
#     'windGustTime': 1560459600,
#     'windBearing': 200,
#     'cloudCover': 0.37,
#     'uvIndex': 10,
#     'uvIndexTime': 1560445200,
#     'visibility': 16.09,
#     'ozone': 289.47,
#     'temperatureMin': 26.64,
#     'temperatureMinTime': 1560416400,
#     'temperatureMax': 32.88,
#     'temperatureMaxTime': 1560456000,
#     'apparentTemperatureMin': 29.04,
#     'apparentTemperatureMinTime': 1560416400,
#     'apparentTemperatureMax': 37.78,
#     'apparentTemperatureMaxTime': 1560456000},
#    {'time': 1560484800,
#     'summary': 'Humid and mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1560508230,
#     'sunsetTime': 1560557678,
#     'moonPhase': 0.41,
#     'precipIntensity': 0.2184,
#     'precipIntensityMax': 0.6172,
#     'precipIntensityMaxTime': 1560546000,
#     'precipProbability': 0.51,
#     'precipType': 'rain',
#     'temperatureHigh': 32.56,
#     'temperatureHighTime': 1560538800,
#     'temperatureLow': 26.91,
#     'temperatureLowTime': 1560592800,
#     'apparentTemperatureHigh': 36.89,
#     'apparentTemperatureHighTime': 1560535200,
#     'apparentTemperatureLow': 29.42,
#     'apparentTemperatureLowTime': 1560592800,
#     'dewPoint': 23.03,
#     'humidity': 0.71,
#     'pressure': 1017.76,
#     'windSpeed': 2.23,
#     'windGust': 6.46,
#     'windGustTime': 1560567600,
#     'windBearing': 79,
#     'cloudCover': 0.76,
#     'uvIndex': 6,
#     'uvIndexTime': 1560528000,
#     'visibility': 16.09,
#     'ozone': 283.6,
#     'temperatureMin': 25.97,
#     'temperatureMinTime': 1560502800,
#     'temperatureMax': 32.56,
#     'temperatureMaxTime': 1560538800,
#     'apparentTemperatureMin': 27.79,
#     'apparentTemperatureMinTime': 1560502800,
#     'apparentTemperatureMax': 36.89,
#     'apparentTemperatureMaxTime': 1560535200},
#    {'time': 1560571200,
#     'summary': 'Rain in the morning.',
#     'icon': 'rain',
#     'sunriseTime': 1560594636,
#     'sunsetTime': 1560644096,
#     'moonPhase': 0.45,
#     'precipIntensity': 0.4547,
#     'precipIntensityMax': 2.0218,
#     'precipIntensityMaxTime': 1560600000,
#     'precipProbability': 0.83,
#     'precipType': 'rain',
#     'temperatureHigh': 30.96,
#     'temperatureHighTime': 1560628800,
#     'temperatureLow': 27.44,
#     'temperatureLowTime': 1560672000,
#     'apparentTemperatureHigh': 34.71,
#     'apparentTemperatureHighTime': 1560628800,
#     'apparentTemperatureLow': 30.13,
#     'apparentTemperatureLowTime': 1560657600,
#     'dewPoint': 22.54,
#     'humidity': 0.7,
#     'pressure': 1018.02,
#     'windSpeed': 4.58,
#     'windGust': 7.25,
#     'windGustTime': 1560578400,
#     'windBearing': 94,
#     'cloudCover': 0.99,
#     'uvIndex': 5,
#     'uvIndexTime': 1560614400,
#     'visibility': 13.41,
#     'ozone': 283.1,
#     'temperatureMin': 26.91,
#     'temperatureMinTime': 1560592800,
#     'temperatureMax': 30.96,
#     'temperatureMaxTime': 1560628800,
#     'apparentTemperatureMin': 29.42,
#     'apparentTemperatureMinTime': 1560592800,
#     'apparentTemperatureMax': 34.71,
#     'apparentTemperatureMaxTime': 1560628800},
#    {'time': 1560657600,
#     'summary': 'Light rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560681042,
#     'sunsetTime': 1560730514,
#     'moonPhase': 0.48,
#     'precipIntensity': 0.2515,
#     'precipIntensityMax': 1.3538,
#     'precipIntensityMaxTime': 1560718800,
#     'precipProbability': 0.69,
#     'precipType': 'rain',
#     'temperatureHigh': 31.52,
#     'temperatureHighTime': 1560708000,
#     'temperatureLow': 27.29,
#     'temperatureLowTime': 1560762000,
#     'apparentTemperatureHigh': 35.6,
#     'apparentTemperatureHighTime': 1560704400,
#     'apparentTemperatureLow': 29.49,
#     'apparentTemperatureLowTime': 1560762000,
#     'dewPoint': 22.38,
#     'humidity': 0.68,
#     'pressure': 1017.46,
#     'windSpeed': 5.02,
#     'windGust': 7.3,
#     'windGustTime': 1560733200,
#     'windBearing': 107,
#     'cloudCover': 0.99,
#     'uvIndex': 5,
#     'uvIndexTime': 1560700800,
#     'visibility': 13.81,
#     'ozone': 293.14,
#     'temperatureMin': 27.44,
#     'temperatureMinTime': 1560672000,
#     'temperatureMax': 31.52,
#     'temperatureMaxTime': 1560708000,
#     'apparentTemperatureMin': 30.13,
#     'apparentTemperatureMinTime': 1560657600,
#     'apparentTemperatureMax': 35.6,
#     'apparentTemperatureMaxTime': 1560704400},
#    {'time': 1560744000,
#     'summary': 'Light rain in the morning.',
#     'icon': 'rain',
#     'sunriseTime': 1560767450,
#     'sunsetTime': 1560816931,
#     'moonPhase': 0.52,
#     'precipIntensity': 0.4674,
#     'precipIntensityMax': 1.1862,
#     'precipIntensityMaxTime': 1560765600,
#     'precipProbability': 0.81,
#     'precipType': 'rain',
#     'temperatureHigh': 29.85,
#     'temperatureHighTime': 1560787200,
#     'temperatureLow': 26.88,
#     'temperatureLowTime': 1560844800,
#     'apparentTemperatureHigh': 32.83,
#     'apparentTemperatureHighTime': 1560787200,
#     'apparentTemperatureLow': 28.72,
#     'apparentTemperatureLowTime': 1560848400,
#     'dewPoint': 21.37,
#     'humidity': 0.65,
#     'pressure': 1017.41,
#     'windSpeed': 5.01,
#     'windGust': 7.38,
#     'windGustTime': 1560783600,
#     'windBearing': 130,
#     'cloudCover': 0.96,
#     'uvIndex': 5,
#     'uvIndexTime': 1560787200,
#     'visibility': 12.07,
#     'ozone': 298.37,
#     'temperatureMin': 27.29,
#     'temperatureMinTime': 1560762000,
#     'temperatureMax': 29.85,
#     'temperatureMaxTime': 1560787200,
#     'apparentTemperatureMin': 29.49,
#     'apparentTemperatureMinTime': 1560762000,
#     'apparentTemperatureMax': 32.83,
#     'apparentTemperatureMaxTime': 1560787200},
#    {'time': 1560830400,
#     'summary': 'Rain starting in the afternoon, continuing until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1560853859,
#     'sunsetTime': 1560903346,
#     'moonPhase': 0.55,
#     'precipIntensity': 0.3708,
#     'precipIntensityMax': 1.7729,
#     'precipIntensityMaxTime': 1560891600,
#     'precipProbability': 0.71,
#     'precipType': 'rain',
#     'temperatureHigh': 31.5,
#     'temperatureHighTime': 1560880800,
#     'temperatureLow': 26.64,
#     'temperatureLowTime': 1560934800,
#     'apparentTemperatureHigh': 34.55,
#     'apparentTemperatureHighTime': 1560880800,
#     'apparentTemperatureLow': 28.56,
#     'apparentTemperatureLowTime': 1560934800,
#     'dewPoint': 21.2,
#     'humidity': 0.63,
#     'pressure': 1017.42,
#     'windSpeed': 3.41,
#     'windGust': 5.83,
#     'windGustTime': 1560913200,
#     'windBearing': 146,
#     'cloudCover': 0.98,
#     'uvIndex': 4,
#     'uvIndexTime': 1560870000,
#     'visibility': 13.2,
#     'ozone': 308.66,
#     'temperatureMin': 26.88,
#     'temperatureMinTime': 1560844800,
#     'temperatureMax': 31.5,
#     'temperatureMaxTime': 1560880800,
#     'apparentTemperatureMin': 28.72,
#     'apparentTemperatureMinTime': 1560848400,
#     'apparentTemperatureMax': 34.55,
#     'apparentTemperatureMaxTime': 1560880800}]},
#  'flags': {'sources': ['nearest-precip',
#    'nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 7.71,
#   'units': 'si'},
#  'offset': -4}

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
